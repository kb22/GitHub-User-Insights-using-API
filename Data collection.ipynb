# %% [markdown]
# # Data collection
#
# In this notebook, I'll use the **GitHub API** to extract various information from my user profile such as repositories, commits and more. I'll also save this data to **.csv** files so that I can draw insights.

# %% [markdown]
# ## Import libraries and defining constants
#
# I'll import various libraries needed for fetching the data.

# %%
import json
import requests
import numpy as np
import pandas as pd

import requests
from requests.auth import HTTPBasicAuth

# %% [markdown]
# I'll fetch the credentials from the json file and create an `authentication` variable.

# %%
credentials = json.loads(open('credentials.json').read())
authentication = HTTPBasicAuth(credentials['username'], credentials['password'])

# %% [markdown]
# ## User information
#
# I'll first extract the user information such as name and related URLs which would be useful ahead.

# %%
data = requests.get('https://api.github.com/users/' + credentials['username'],
                    auth = authentication)
data = data.json()
data
# Out:
# {'login': 'kb22',
#  'id': 14316277,
#  'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#  'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/kb22',
#  'html_url': 'https://github.com/kb22',
#  'followers_url': 'https://api.github.com/users/kb22/followers',
#  'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#  'organizations_url': 'https://api.github.com/users/kb22/orgs',
#  'repos_url': 'https://api.github.com/users/kb22/repos',
#  'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/kb22/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Karan Bhanot',
#  'company': 'Cvent',
#  'blog': 'https://medium.com/@bhanotkaran22',
#  'location': 'India',
#  'email': 'bhanotkaran22@gmail.com',
#  'hireable': True,
#  'bio': 'Working with Python, Machine Learning and Deep Learning to explore the field of Data Science and Machine Learning.',
#  'public_repos': 36,
#  'public_gists': 208,
#  'followers': 35,
#  'following': 0,
#  'created_at': '2015-09-16T16:14:22Z',
#  'updated_at': '2019-06-21T06:51:40Z',
#  'private_gists': 2,
#  'total_private_repos': 0,
#  'owned_private_repos': 0,
#  'disk_usage': 155369,
#  'collaborators': 0,
#  'two_factor_authentication': False,
#  'plan': {'name': 'free',
#   'space': 976562499,
#   'collaborators': 0,
#   'private_repos': 10000}}

# %% [markdown]
# From the json output above, I'll try to extract basic information such as `name`, `location`, `email`, `bio`, `public_repos`, and `public gists`. I'll also keep some of the urls handy inluding `repos_url`, `gists_url` and `blog`.

# %%
print("Information about user {}:\n".format(credentials['username']))
print("Name: {}".format(data['name']))
print("Email: {}".format(data['email']))
print("Location: {}".format(data['location']))
print("Public repos: {}".format(data['public_repos']))
print("Public gists: {}".format(data['public_gists']))
print("About: {}".format(data['bio']))
# Out:
# Information about user kb22:
#
# Name: Karan Bhanot
# Email: bhanotkaran22@gmail.com
# Location: India
# Public repos: 36
# Public gists: 208
# About: Working with Python, Machine Learning and Deep Learning to explore the field of Data Science and Machine Learning.

# %% [markdown]
# ## Repositories
#
# Next, I'll fetch repositories for the user.

# %%
REPOS_URL = data['repos_url']
repos_data = requests.get(REPOS_URL, auth = authentication)
repos_data = repos_data.json()

# %% [markdown]
# I'll first explore only one repository information and take a look at all the information I can keep.

# %%
repos_data[0]
# Out:
# {'id': 154344656,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNTQzNDQ2NTY=',
#  'name': 'Activity-Recognition-using-Machine-Learning',
#  'full_name': 'kb22/Activity-Recognition-using-Machine-Learning',
#  'private': False,
#  'owner': {'login': 'kb22',
#   'id': 14316277,
#   'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kb22',
#   'html_url': 'https://github.com/kb22',
#   'followers_url': 'https://api.github.com/users/kb22/followers',
#   'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#   'organizations_url': 'https://api.github.com/users/kb22/orgs',
#   'repos_url': 'https://api.github.com/users/kb22/repos',
#   'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/kb22/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning',
#  'description': 'Use machine learning to classify various activities.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning',
#  'forks_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/forks',
#  'keys_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/teams',
#  'hooks_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/hooks',
#  'issue_events_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/events',
#  'assignees_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/tags',
#  'blobs_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/languages',
#  'stargazers_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/stargazers',
#  'contributors_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/contributors',
#  'subscribers_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/subscribers',
#  'subscription_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/subscription',
#  'commits_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/merges',
#  'archive_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/downloads',
#  'issues_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/deployments',
#  'created_at': '2018-10-23T14:40:38Z',
#  'updated_at': '2019-04-30T08:00:17Z',
#  'pushed_at': '2018-10-29T13:10:27Z',
#  'git_url': 'git://github.com/kb22/Activity-Recognition-using-Machine-Learning.git',
#  'ssh_url': 'git@github.com:kb22/Activity-Recognition-using-Machine-Learning.git',
#  'clone_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning.git',
#  'svn_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning',
#  'homepage': None,
#  'size': 25570,
#  'stargazers_count': 1,
#  'watchers_count': 1,
#  'language': 'Jupyter Notebook',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 3,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': {'key': 'mit',
#   'name': 'MIT License',
#   'spdx_id': 'MIT',
#   'url': 'https://api.github.com/licenses/mit',
#   'node_id': 'MDc6TGljZW5zZTEz'},
#  'forks': 3,
#  'open_issues': 0,
#  'watchers': 1,
#  'default_branch': 'master',
#  'permissions': {'admin': True, 'push': True, 'pull': True}}

# %% [markdown]
# There are a number of things that we can keep a track of here. I'll select the following:
# 1. id: Unique id for the repository.
# 2. name: The name of the repository.
# 3. description: The description of the repository.
# 4. created_at: The time and date when the repository was first created.
# 5. updated_at: The time and date when the repository was last updated.
# 6. login: Username of the owner of the repository.
# 7. license: The license type (if any).
# 8. has_wiki: A boolean that signifies if the repository has a wiki document.
# 9. forks_count: Total forks of the repository.
# 10. open_issues_count: Total issues opened in the repository.
# 11. stargazers_count: The total stars on the reepository.
# 12. watchers_count: Total users watching the repository.

# %% [markdown]
# I'll also keep track of some urls for further analysis including:
# 1. url: The url of the repository.
# 2. commits_url: The url for all commits in the repository.
# 3. languages_url: The url for all languages in the repository.
#
# The commit url, I'll remove the end value inside the braces.

# %%
repos_information = []
for i, repo in enumerate(repos_data):
    data = []
    data.append(repo['id'])
    data.append(repo['name'])
    data.append(repo['description'])
    data.append(repo['created_at'])
    data.append(repo['updated_at'])
    data.append(repo['owner']['login'])
    data.append(repo['license']['name'] if repo['license'] != None else None)
    data.append(repo['has_wiki'])
    data.append(repo['forks_count'])
    data.append(repo['open_issues_count'])
    data.append(repo['stargazers_count'])
    data.append(repo['watchers_count'])
    data.append(repo['url'])
    data.append(repo['commits_url'].split("{")[0])
    data.append(repo['url'] + '/languages')
    repos_information.append(data)

# %%
repos_df = pd.DataFrame(repos_information, columns = ['Id', 'Name', 'Description', 'Created on', 'Updated on', 
                                                      'Owner', 'License', 'Includes wiki', 'Forks count', 
                                                      'Issues count', 'Stars count', 'Watchers count',
                                                      'Repo URL', 'Commits URL', 'Languages URL'])
repos_df.head(10)
# Out:
#           Id                                         Name  \
# 0  154344656  Activity-Recognition-using-Machine-Learning
# 1   98045107                               Animation-in-C
# 2  175083480                          Article-Recommender
# 3  104722536                            Attendance-Marker
# 4  161978072  Color-Identification-using-Machine-Learning
# 5   98046895            Computer-Simulation-using-Proteus
# 6  186462080                            Coursera_Capstone
# 7  149577869                     Create-dataset-using-API
# 8  173539133                 Create-Face-Data-from-Images
# 9  183209160                 Deep-Learning-A-Z-Coursework
#
#                                          Description            Created on  \
# 0  Use machine learning to classify various activ...  2018-10-23T14:40:38Z
# 1  A frame by frame Animation designed in C Langu...  2017-07-22T16:52:58Z
# 2  Using LDA, the project recommends Wikipedia ar...  2019-03-11T21:04:20Z
# 3   A QR Code based attendance tracking application.  2017-09-25T08:20:58Z
# 4  This project uses Machine Learning to extract ...  2018-12-16T07:27:38Z
# 5  Simulated the functioning of a basic computer ...  2017-07-22T17:23:04Z
# 6  The repository will include code for the Capst...  2019-05-13T17:00:15Z
# 7  A Python notebook to create a dataset through ...  2018-09-20T08:36:38Z
# 8  Using OpenCV Face Detection Neural Network to ...  2019-03-03T06:24:15Z
# 9  The project includes all the files for the Dee...  2019-04-24T10:48:09Z
#
#              Updated on Owner                          License  Includes wiki  \
# 0  2019-04-30T08:00:17Z  kb22                      MIT License           True
# 1  2017-07-22T17:06:23Z  kb22                             None           True
# 2  2019-06-17T12:54:23Z  kb22                      MIT License           True
# 3  2017-09-25T08:22:21Z  kb22                             None           True
# 4  2019-06-19T08:26:32Z  kb22                      MIT License           True
# 5  2017-07-22T17:23:04Z  kb22                             None           True
# 6  2019-06-17T08:10:53Z  kb22                             None           True
# 7  2019-06-20T19:07:44Z  kb22                             None           True
# 8  2019-06-09T12:34:33Z  kb22                             None           True
# 9  2019-06-05T21:49:42Z  kb22  GNU General Public License v3.0           True
#
#    Forks count  Issues count  Stars count  Watchers count  \
# 0            3             0            1               1
# 1            0             0            0               0
# 2            2             0            3               3
# 3            0             0            0               0
# 4            3             0           11              11
# 5            0             0            0               0
# 6            1             0            0               0
# 7            7             0            3               3
# 8            4             0            5               5
# 9            0             0            2               2
#
#                                             Repo URL  \
# 0  https://api.github.com/repos/kb22/Activity-Rec...
# 1   https://api.github.com/repos/kb22/Animation-in-C
# 2  https://api.github.com/repos/kb22/Article-Reco...
# 3  https://api.github.com/repos/kb22/Attendance-M...
# 4  https://api.github.com/repos/kb22/Color-Identi...
# 5  https://api.github.com/repos/kb22/Computer-Sim...
# 6  https://api.github.com/repos/kb22/Coursera_Cap...
# 7  https://api.github.com/repos/kb22/Create-datas...
# 8  https://api.github.com/repos/kb22/Create-Face-...
# 9  https://api.github.com/repos/kb22/Deep-Learnin...
#
#                                          Commits URL  \
# 0  https://api.github.com/repos/kb22/Activity-Rec...
# 1  https://api.github.com/repos/kb22/Animation-in...
# 2  https://api.github.com/repos/kb22/Article-Reco...
# 3  https://api.github.com/repos/kb22/Attendance-M...
# 4  https://api.github.com/repos/kb22/Color-Identi...
# 5  https://api.github.com/repos/kb22/Computer-Sim...
# 6  https://api.github.com/repos/kb22/Coursera_Cap...
# 7  https://api.github.com/repos/kb22/Create-datas...
# 8  https://api.github.com/repos/kb22/Create-Face-...
# 9  https://api.github.com/repos/kb22/Deep-Learnin...
#
#                                        Languages URL
# 0  https://api.github.com/repos/kb22/Activity-Rec...
# 1  https://api.github.com/repos/kb22/Animation-in...
# 2  https://api.github.com/repos/kb22/Article-Reco...
# 3  https://api.github.com/repos/kb22/Attendance-M...
# 4  https://api.github.com/repos/kb22/Color-Identi...
# 5  https://api.github.com/repos/kb22/Computer-Sim...
# 6  https://api.github.com/repos/kb22/Coursera_Cap...
# 7  https://api.github.com/repos/kb22/Create-datas...
# 8  https://api.github.com/repos/kb22/Create-Face-...
# 9  https://api.github.com/repos/kb22/Deep-Learnin...

# %% [markdown]
# ## Languages
#
# For topics of each repository, I'll iterate through all repos' `Languagues URL` and get the corresponding data. I'll also store them back to the dataframe.

# %%
for i in range(repos_df.shape[0]):
    response = requests.get(repos_df.loc[i, 'Languages URL'], auth = authentication)
    response = response.json()
    print(i, response)
    if response != {}:
        languages = []
        for key, value in response.items():
            languages.append(key)
        languages = ', '.join(languages)
        repos_df.loc[i, 'Languages'] = languages
    else:
        repos_df.loc[i, 'Languages'] = ""
# Out:
# 0 {'Jupyter Notebook': 2080768}
# 1 {'C': 196326}
# 2 {'Python': 8506}
# 3 {'Java': 17850}
# 4 {'Jupyter Notebook': 4152085}
# 5 {}
# 6 {'Jupyter Notebook': 1789648, 'HTML': 427681}
# 7 {'Jupyter Notebook': 20657}
# 8 {'Python': 2871}
# 9 {'Jupyter Notebook': 295254}
# 10 {'Jupyter Notebook': 85404}
# 11 {'Python': 3034}
# 12 {'Jupyter Notebook': 47204}
# 13 {'Jupyter Notebook': 261173}
# 14 {'Jupyter Notebook': 39932}
# 15 {'Java': 67597, 'PHP': 6386}
# 16 {'Jupyter Notebook': 519792}
# 17 {'HTML': 5632, 'JavaScript': 3664, 'CSS': 2389}
# 18 {'Jupyter Notebook': 1089017}
# 19 {'Jupyter Notebook': 119427}
# 20 {'Jupyter Notebook': 299710}
# 21 {'JavaScript': 21089, 'Python': 4965, 'HTML': 3208, 'CSS': 2327}
# 22 {'PHP': 28283, 'CSS': 20740}
# 23 {'HTML': 72173955, 'Jupyter Notebook': 185823}
# 24 {'Jupyter Notebook': 147471}
# 25 {'C++': 3726}
# 26 {'Java': 24850}
# 27 {'Java': 17705}
# 28 {'Jupyter Notebook': 333190, 'Python': 6086}
# 29 {'Python': 2045}

# %% [markdown]
# I'll publish this data into a .csv file called **repos_info.csv**

# %%
repos_df.to_csv('repos_info.csv', index = False)

# %% [markdown]
# ## Commits
#
# I'll now also create a dataset with all the commits done till now.

# %%
response = requests.get(repos_df.loc[0, 'Commits URL'], auth = authentication)
response.json()
# Out:
# [{'sha': '62bf829df5045ed10787551b46a1ae1cc103e1d2',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OjYyYmY4MjlkZjUwNDVlZDEwNzg3NTUxYjQ2YTFhZTFjYzEwM2UxZDI=',
#   'commit': {'author': {'name': 'Karan Bhanot',
#     'email': 'bhanotkaran22@gmail.com',
#     'date': '2018-10-29T13:10:26Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2018-10-29T13:10:26Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '24e087e5aab5ccdf19451665672ae2a4930c6ceb',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/24e087e5aab5ccdf19451665672ae2a4930c6ceb'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/62bf829df5045ed10787551b46a1ae1cc103e1d2',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=0sEU\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 24e087e5aab5ccdf19451665672ae2a4930c6ceb\nparent a49bf9574b3f4170a5baf27ef8664e9a053ccaed\nauthor Karan Bhanot <bhanotkaran22@gmail.com> 1540818626 +0530\ncommitter GitHub <noreply@github.com> 1540818626 +0530\n\nUpdate README.md'}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/62bf829df5045ed10787551b46a1ae1cc103e1d2',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/62bf829df5045ed10787551b46a1ae1cc103e1d2',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/62bf829df5045ed10787551b46a1ae1cc103e1d2/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/a49bf9574b3f4170a5baf27ef8664e9a053ccaed'}]},
#  {'sha': 'a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OmE0OWJmOTU3NGIzZjQxNzBhNWJhZjI3ZWY4NjY0ZTlhMDUzY2NhZWQ=',
#   'commit': {'author': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-27T17:11:37Z'},
#    'committer': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-27T17:11:37Z'},
#    'message': 'Remove unused imports',
#    'tree': {'sha': '6ece4944368423244dad762190d23af678a1a3ec',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/6ece4944368423244dad762190d23af678a1a3ec'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/a49bf9574b3f4170a5baf27ef8664e9a053ccaed',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/a49bf9574b3f4170a5baf27ef8664e9a053ccaed/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c13241c5428628f63d44dd1e7a1e568f930dd05b',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/c13241c5428628f63d44dd1e7a1e568f930dd05b',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/c13241c5428628f63d44dd1e7a1e568f930dd05b'}]},
#  {'sha': 'c13241c5428628f63d44dd1e7a1e568f930dd05b',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OmMxMzI0MWM1NDI4NjI4ZjYzZDQ0ZGQxZTdhMWU1NjhmOTMwZGQwNWI=',
#   'commit': {'author': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-27T15:31:59Z'},
#    'committer': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-27T15:31:59Z'},
#    'message': 'Use test.csv for testing',
#    'tree': {'sha': 'b312edc563493219762e078489a6b02396885bc1',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/b312edc563493219762e078489a6b02396885bc1'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/c13241c5428628f63d44dd1e7a1e568f930dd05b',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/c13241c5428628f63d44dd1e7a1e568f930dd05b',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/c13241c5428628f63d44dd1e7a1e568f930dd05b',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/c13241c5428628f63d44dd1e7a1e568f930dd05b/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '050ef708c4334382d06fd1dc8061ed14d58da6b4',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/050ef708c4334382d06fd1dc8061ed14d58da6b4',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/050ef708c4334382d06fd1dc8061ed14d58da6b4'}]},
#  {'sha': '050ef708c4334382d06fd1dc8061ed14d58da6b4',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OjA1MGVmNzA4YzQzMzQzODJkMDZmZDFkYzgwNjFlZDE0ZDU4ZGE2YjQ=',
#   'commit': {'author': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-25T10:50:27Z'},
#    'committer': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-25T10:50:27Z'},
#    'message': 'Use machine learning algorithms',
#    'tree': {'sha': '3978903b9cbcf4db5db1ffc0fc6d795aae2d0679',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/3978903b9cbcf4db5db1ffc0fc6d795aae2d0679'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/050ef708c4334382d06fd1dc8061ed14d58da6b4',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/050ef708c4334382d06fd1dc8061ed14d58da6b4',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/050ef708c4334382d06fd1dc8061ed14d58da6b4',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/050ef708c4334382d06fd1dc8061ed14d58da6b4/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '48593306b25ad2456fc55131a73e78a1405e62db',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/48593306b25ad2456fc55131a73e78a1405e62db',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/48593306b25ad2456fc55131a73e78a1405e62db'}]},
#  {'sha': '48593306b25ad2456fc55131a73e78a1405e62db',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OjQ4NTkzMzA2YjI1YWQyNDU2ZmM1NTEzMWE3M2U3OGExNDA1ZTYyZGI=',
#   'commit': {'author': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-24T16:06:06Z'},
#    'committer': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-24T16:06:06Z'},
#    'message': 'Add visualizations of the dataset',
#    'tree': {'sha': '723020914a24f4bf00bda4e62b85b6d1ad7f4247',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/723020914a24f4bf00bda4e62b85b6d1ad7f4247'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/48593306b25ad2456fc55131a73e78a1405e62db',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/48593306b25ad2456fc55131a73e78a1405e62db',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/48593306b25ad2456fc55131a73e78a1405e62db',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/48593306b25ad2456fc55131a73e78a1405e62db/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100'}]},
#  {'sha': '8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OjgzNTVmYzk2ZTViNWQ0M2ZiN2FhYmM0Y2I4NDdhYjk4MGU1YmExMDA=',
#   'commit': {'author': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-24T07:59:58Z'},
#    'committer': {'name': 'Bhanot, Karan',
#     'email': 'k.bhanot@cvent.com',
#     'date': '2018-10-24T07:59:58Z'},
#    'message': 'Initial commit',
#    'tree': {'sha': '34eda2db27b1175d2bb0bdb8cbbc889ec503858e',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/34eda2db27b1175d2bb0bdb8cbbc889ec503858e'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/8355fc96e5b5d43fb7aabc4cb847ab980e5ba100/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#     'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/2ff2ac6e3344dcf679adab4e21ee830aa5351188'}]},
#  {'sha': '2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#   'node_id': 'MDY6Q29tbWl0MTU0MzQ0NjU2OjJmZjJhYzZlMzM0NGRjZjY3OWFkYWI0ZTIxZWU4MzBhYTUzNTExODg=',
#   'commit': {'author': {'name': 'Karan Bhanot',
#     'email': 'bhanotkaran22@gmail.com',
#     'date': '2018-10-23T14:40:40Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2018-10-23T14:40:40Z'},
#    'message': 'Initial commit',
#    'tree': {'sha': '7e3f8b1013a64f622d429f02648125c406ae9741',
#     'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/trees/7e3f8b1013a64f622d429f02648125c406ae9741'},
#    'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/git/commits/2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=VlwJ\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7e3f8b1013a64f622d429f02648125c406ae9741\nauthor Karan Bhanot <bhanotkaran22@gmail.com> 1540305640 +0530\ncommitter GitHub <noreply@github.com> 1540305640 +0530\n\nInitial commit'}},
#   'url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#   'html_url': 'https://github.com/kb22/Activity-Recognition-using-Machine-Learning/commit/2ff2ac6e3344dcf679adab4e21ee830aa5351188',
#   'comments_url': 'https://api.github.com/repos/kb22/Activity-Recognition-using-Machine-Learning/commits/2ff2ac6e3344dcf679adab4e21ee830aa5351188/comments',
#   'author': {'login': 'kb22',
#    'id': 14316277,
#    'node_id': 'MDQ6VXNlcjE0MzE2Mjc3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14316277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kb22',
#    'html_url': 'https://github.com/kb22',
#    'followers_url': 'https://api.github.com/users/kb22/followers',
#    'following_url': 'https://api.github.com/users/kb22/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kb22/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kb22/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kb22/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kb22/orgs',
#    'repos_url': 'https://api.github.com/users/kb22/repos',
#    'events_url': 'https://api.github.com/users/kb22/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kb22/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': []}]

# %% [markdown]
# I'll save the id, date and the message of each commit.

# %%
commits_information = []
for i in range(repos_df.shape[0]):
    response = requests.get(repos_df.loc[i, 'Commits URL'], auth = authentication)
    response = response.json()
    for commit in response:
        commit_data = []
        commit_data.append(commit['sha'])
        commit_data.append(commit['commit']['committer']['date'])
        commit_data.append(commit['commit']['message'])
        commits_information.append(commit_data)

# %%
commits_df = pd.DataFrame(commits_information, columns = ['Id', 'Date', 'Message'])
commits_df.head(5)
# Out:
#                                          Id                  Date  \
# 0  62bf829df5045ed10787551b46a1ae1cc103e1d2  2018-10-29T13:10:26Z
# 1  a49bf9574b3f4170a5baf27ef8664e9a053ccaed  2018-10-27T17:11:37Z
# 2  c13241c5428628f63d44dd1e7a1e568f930dd05b  2018-10-27T15:31:59Z
# 3  050ef708c4334382d06fd1dc8061ed14d58da6b4  2018-10-25T10:50:27Z
# 4  48593306b25ad2456fc55131a73e78a1405e62db  2018-10-24T16:06:06Z
#
#                              Message
# 0                   Update README.md
# 1              Remove unused imports
# 2           Use test.csv for testing
# 3    Use machine learning algorithms
# 4  Add visualizations of the dataset

# %% [markdown]
# I'll publish this data into a .csv file called **commits_info.csv**

# %%
commits_df.to_csv('commits_info.csv', index = False)
